# %%
import os
import uuid
import imageio
import numpy as np
import torch
from IPython.display import Image as ImageDisplay
import sys
PATH = os.getcwd()
module_dir = os.path.abspath(f"{PATH}/../../sam-3d-objects/notebook/")
sys.path.append(module_dir)
from inference import Inference, ready_gaussian_for_video_rendering, load_image, load_mask, display_image, make_scene, render_video, interactive_visualizer
import imageio.v3 as iio
from pytorch3d.transforms import quaternion_to_matrix, Transform3d
# Out:
# /home/haihong/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Warp 1.11.1 initialized:
#    CUDA Toolkit 12.9, Driver 12.8
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA RTX 2000 Ada Generation" (16 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/haihong/.cache/warp/1.11.1
# 2026-03-30 22:54:16.538 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:15 - GPU name is NVIDIA RTX 2000 Ada Generation
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2026-03-30 22:54:18.234 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# 2026-03-30 22:54:20.486 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.attention:__from_env:30 - [ATTENTION] Using backend: sdpa
# [SPARSE][CONV] spconv algo: auto
# 2026-03-30 22:54:20.792 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-03-30 22:54:20.793 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift

# %%
PATH = os.getcwd()
TAG = "hf"
config_path = f"{PATH}/../../sam-3d-objects/checkpoints/{TAG}/pipeline.yaml"
inference = Inference(config_path, compile=False)
# Out:
# 2026-03-30 22:54:20.822 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# /home/haihong/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/moge/model/v1.py:171: UserWarning: The following deprecated/invalid arguments are ignored: {'output_mask': True, 'split_head': True}
#   warnings.warn(f"The following deprecated/invalid arguments are ignored: {deprecated_kwargs}")
# 2026-03-30 22:54:26.070 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-03-30 22:54:26.072 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:98 - self.device: cuda
# 2026-03-30 22:54:26.073 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:99 - CUDA_VISIBLE_DEVICES: None
# 2026-03-30 22:54:26.073 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:100 - Actually using GPU: 0
# 2026-03-30 22:54:26.073 | INFO     | sam3d_objects.pipeline.inference_pipeline:init_pose_decoder:295 - Using pose decoder: ScaleShiftInvariant
# 2026-03-30 22:54:26.074 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:131 - Loading model weights...
# 2026-03-30 22:54:26.339 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/ss_generator.ckpt
# 2026-03-30 22:54:37.182 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/slat_generator.ckpt
# 2026-03-30 22:54:40.682 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/ss_decoder.ckpt
# 2026-03-30 22:54:41.073 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/slat_decoder_gs.ckpt
# 2026-03-30 22:54:41.250 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/slat_decoder_gs_4.ckpt
# 2026-03-30 22:54:41.499 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/slat_decoder_mesh.ckpt
# 2026-03-30 22:54:41.969 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-03-30 22:54:42.843 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-03-30 22:54:42.846 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-03-30 22:54:43.351 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-03-30 22:54:43.364 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/ss_generator.ckpt
# 2026-03-30 22:54:48.319 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-03-30 22:54:49.065 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-03-30 22:54:49.069 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-03-30 22:54:49.453 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-03-30 22:54:49.500 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../../sam-3d-objects/checkpoints/hf/slat_generator.ckpt
# 2026-03-30 22:54:53.381 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_ss_generator_cfg_config:436 - ss_generator parameters: inference_steps=25, cfg_strength=7, cfg_interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-03-30 22:54:53.382 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_slat_generator_cfg_config:458 - slat_generator parameters: inference_steps=25, cfg_strength=1, cfg_interval=[0, 500], rescale_t=1
# 2026-03-30 22:54:53.382 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:196 - Loading model weights completed!

# %%
IMAGE_PATH = f"{PATH}/../../tracking_dataset/ACE_data/ACE/orbit_45deg_left_back/image/20260120170217059.png"
MASK_PATH = f"{PATH}/../../tracking_dataset/ACE_data/ACE/orbit_45deg_left_back/seg/20260120170217059.png"

image = load_image(IMAGE_PATH)
mask = load_mask(MASK_PATH)

display_image(image, [mask,])
# Out:
# /home/haihong/sam-3d-objects/notebook/inference.py:404: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def generate_sam3d_pointmap_50deg(depth_path):
    # Load Depth
    depth_data = np.load(depth_path)
    raw_depth = depth_data['depth'].astype(np.float32) 
    depth = raw_depth / 1000.0
    
    # New Parameters for 50 degree FOV, 1024x1024
    f_val = 1098.05
    c_val = 512.0
    
    h, w = depth.shape
    u, v = np.meshgrid(np.arange(w), np.arange(h))
    
    # Unproject to 3D Camera Space
    z = depth
    x = (u - c_val) * z / f_val
    y = (v - c_val) * z / f_val
    
    # Shape (1024, 1024, 3)
    pointmap = np.stack([-x, -y, z], axis=-1)
    return pointmap

depth_path = f"{PATH}/../../tracking_dataset/ACE_data/ACE/orbit_45deg_left_back/depth/20260120170217059.npz"
pointmap = generate_sam3d_pointmap_50deg(depth_path)
pointmaP = torch.tensor(pointmap, dtype=torch.float32)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
# Set labels
ax.set_xlabel('X (Horizontal)')
ax.set_ylabel('Y (Vertical)')
ax.set_zlabel('Z (Depth)')
ax.set_title('SAM3D Masked Object Reconstruction')


binary_mask = torch.from_numpy(mask)
print(binary_mask.shape)
y_indices, x_indices = torch.where(binary_mask > 0)
# y_indices = y_indices.to(points.device)
# x_indices = x_indices.to(points.device)
filtered_points = pointmap[y_indices, x_indices]
pts = filtered_points[::50]

xs, ys, zs = pts[:, 0], pts[:, 1], pts[:, 2]
img = ax.scatter(xs, ys, zs, label=f'Satellite', s=5, alpha=0.8)
    
ax.legend()
plt.show()
# Out:
# torch.Size([1024, 1024])

# %%
outputs = inference(image, mask, seed=42,pointmap=pointmaP)
# Out:
# 2026-03-30 22:59:41.459 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-03-30 22:59:41.459 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2026-03-30 22:59:41.990 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2026-03-30 22:59:58.714 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 3651 to 3651
# 2026-03-30 22:59:58.726 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2026-03-30 22:59:58.727 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2026-03-30 22:59:58.727 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2026-03-30 22:59:58.843 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2026-03-30 23:00:02.651 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2026-03-30 23:00:07.213 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2026-03-30 23:00:07.260 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!

# %%
save_path = f"{PATH}/../ACE_results/sam3d_object_cache_ptmp_input.pt"
torch.save(outputs, save_path)

# %%
outputs = torch.load(f"{PATH}/../ACE_results/sam3d_object_cache_ptmp_input.pt")
IMAGE_NAME = "20260120170217059"

scene_gs = make_scene(*[outputs,])
scene_gs = ready_gaussian_for_video_rendering(scene_gs,fix_alignment=False)

# export gaussian splatting (as point cloud)
scene_gs.save_ply(f"{PATH}/../ACE_results/{IMAGE_NAME}.ply")

video = render_video(
    scene_gs,
    r=1,
    fov=60,
    resolution=512,
)["color"]
 
# save video as gif
imageio.mimsave(
    os.path.join(f"{PATH}/../ACE_results/{IMAGE_NAME}.gif"),
    video,
    format="GIF",
    duration=1000 / 30,  # default assuming 30fps from the input MP4
    loop=0,  # 0 means loop indefinitely
)

# notebook display
ImageDisplay(url=f"{PATH}/../ACE_results/{IMAGE_NAME}.gif?cache_invalidator={uuid.uuid4()}",)
# Out:
# /tmp/ipykernel_28797/195409444.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   outputs = torch.load(f"{PATH}/../ACE_results/sam3d_object_cache_ptmp_input.pt")
# Rendering: 300it [00:01, 207.48it/s]
# <img src="/home/haihong/Multi-object-tracking-reconstruction/notebook_playground/../ACE_results/20260120170217059.gif?cache_invalidator=86a084fe-d6c3-4447-9189-50801a33294a"/>

# %%
module_dir = os.path.abspath(f"{PATH}/../")
if module_dir not in sys.path:
    sys.path.append(module_dir)

from alignment_pipeline import (
    apply_moge_transform, estimate_transform, 
    extract_corresponding_points, transform_mesh_data,
    get_o3d_geometries, visualize_all_overlays
)

outputs = torch.load(f"{PATH}/../ACE_results/sam3d_object_cache_ptmp_input.pt")
mesh = outputs["glb"].copy()
aligned_mesh = apply_moge_transform(mesh, outputs)
# Out:
# /tmp/ipykernel_28797/515176281.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   outputs = torch.load(f"{PATH}/../ACE_results/sam3d_object_cache_ptmp_input.pt")
# tensor([[126.5699, 126.5699, 126.5699]], device='cuda:0') tensor([[0.3418, 0.3880, 0.6253, 0.5845]], device='cuda:0') tensor([[-165.9122, -131.1784, -312.9586]], device='cuda:0')

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
# Set labels
ax.set_xlabel('X (Horizontal)')
ax.set_ylabel('Y (Vertical)')
ax.set_zlabel('Z (Depth)')
ax.set_title('SAM3D Masked Object Reconstruction')
points = outputs.get('pointmap')
binary_mask = torch.from_numpy(mask)
print(binary_mask.shape)
y_indices, x_indices = torch.where(binary_mask > 0)
filtered_points = points[y_indices, x_indices].reshape(-1, 3)
points_sampled = filtered_points[::100]
print(points_sampled.shape)

xs, ys, zs = points_sampled[:, 0], points_sampled[:, 1], points_sampled[:, 2]
img = ax.scatter(xs, ys, zs, label=f'sam3d output pointmap', s=5, alpha=0.8)
    
ax.legend()
plt.show()
# Out:
# torch.Size([1024, 1024])
# torch.Size([161, 3])

# %%
import open3d as o3d
import torch.nn.functional as F
geometries = []

points = outputs.get('pointmap')
colors = outputs.get('pointmap_colors')

binary_mask = torch.from_numpy(mask)
y_indices, x_indices = torch.where(binary_mask > 0)
y_indices = y_indices.to(points.device)
x_indices = x_indices.to(points.device)
filtered_points = points[y_indices, x_indices]
filtered_colors = colors[y_indices, x_indices]
flat_points = filtered_points.reshape(-1, 3)
flat_colors = filtered_colors.reshape(-1, 3)
if flat_colors.max() > 1.0:
    flat_colors = flat_colors / 255.0
valid_idx = ~(flat_points == 0).all(dim=1)
final_points = flat_points[valid_idx]
final_colors = flat_colors[valid_idx]
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(final_points)
pcd.colors = o3d.utility.Vector3dVector(final_colors)
geometries.append(pcd)

mesh_o3d = o3d.geometry.TriangleMesh()
mesh_o3d.vertices = o3d.utility.Vector3dVector(np.asarray(outputs["glb"].vertices))
mesh_o3d.triangles = o3d.utility.Vector3iVector(np.asarray(outputs["glb"].faces))
mesh_o3d.compute_vertex_normals()
mesh_o3d.paint_uniform_color([1, 0, 0])
geometries.append(mesh_o3d)

aligned_mesh_o3d = o3d.geometry.TriangleMesh()
aligned_mesh_o3d.vertices = o3d.utility.Vector3dVector(np.asarray(aligned_mesh.vertices))
aligned_mesh_o3d.triangles = o3d.utility.Vector3iVector(np.asarray(aligned_mesh.faces))
aligned_mesh_o3d.compute_vertex_normals()
aligned_mesh_o3d.paint_uniform_color([0, 1, 0])
geometries.append(aligned_mesh_o3d)

origin = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.5)
geometries.append(origin)
o3d.visualization.draw_geometries(geometries)

# %%
print(outputs.keys())
print(outputs["6drotation_normalized"])
# Out:
# dict_keys(['6drotation_normalized', 'scale', 'shape', 'translation', 'translation_scale', 'coords_original', 'coords', 'downsample_factor', 'rotation', 'mesh', 'gaussian', 'glb', 'gs', 'pointmap', 'pointmap_colors'])
# tensor([[[-0.6147,  1.3126,  0.0864,  0.2018,  0.0347,  0.7950]]],
#        device='cuda:0')

# %%
t_est = outputs.get('translation') # Extract translation from 4x4 matrix
t_scale = outputs.get('translation_scale')
print(f"Point Cloud Mean Z: {final_points[:, 2].mean():.4f}m")
print(f"Mesh Translation Z: {(t_est, t_scale)}")
# Out:
# Point Cloud Mean Z: 15.3598m
# Mesh Translation Z: (tensor([[-165.9122, -131.1784, -312.9586]], device='cuda:0'), tensor([[[0.0753]]], device='cuda:0'))

# %%
# TDOO: why does the estimated transformation have problem??
